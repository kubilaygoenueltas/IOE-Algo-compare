# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import quaternion_angle as qa
from pathlib import Path
import os

# %%
out = np.loadtxt("C:/Users/kubil/Documents/STUDIUM/Master/4_Masterarbeit_Code/IOE-Algo-compare/imu-constraint-cpp-el-wr-main/out/out.txt")

# %%
q1 = out[:, 4:8]
q2 = out[:, 8:12]

# %%
qa_kr = qa.quaternion_angle(q1, q2)

# %%
plt.plot(qa_kr, label="Knie rechts")
plt.grid()
plt.legend()
plt.ylabel("Knee Angle [deg]")
plt.xlabel("Time [s]")
plt.show()
